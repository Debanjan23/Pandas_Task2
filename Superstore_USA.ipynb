# %%
import pandas as p

# %%
df2 = p.read_excel(r'C:\Users\dchakrab.COMPUTACENTER\Downloads\Superstore_USA.xlsx')

# %%
df2.dtypes
# Out:
# Row ID                                     int64
# Order Priority                            object
# Discount                                 float64
# Unit Price                               float64
# Shipping Cost                            float64
# Customer ID                                int64
# Customer Name                             object
# Ship Mode                                 object
# Customer Segment                          object
# Product Category                          object
# Product Sub-Category                      object
# Product Container                         object
# Product Name                              object
# Product Base Margin                      float64
# Region                                    object
# State or Province                         object
# City                                      object
# Postal Code                                int64
# Order Date                        datetime64[ns]
# ...

# %%
df2.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df3 = p.read_excel(r'C:\Users\dchakrab.COMPUTACENTER\Downloads\Superstore_USA.xlsx', sheet_name = "Returns")

# %%
df4 = p.read_excel(r'C:\Users\dchakrab.COMPUTACENTER\Downloads\Superstore_USA.xlsx', sheet_name = "Users")

# %% [markdown]
# >>>>>>>>>>>>>>>>Joininig order and returns data>>>>>>>>>>>>>>>>>>>

# %%
df5_Orders_returns = p.merge(df2,df3, on = 'Order ID')

# %%
df5_Orders_returns
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %%
>>>>>>>>Find Out How many Unique customers we have>>>>>>>>>>

# %%
len(p.unique(df2['Customer ID']))
# Out:
# 2703

# %% [markdown]
# >>>>>>>>>>>>>>>>>>Find out how many returns that we ahve recived and with a product id>>>>>>>>>>>>>>>>>>

# %%
df5_Orders_returns.dtypes
# Out:
# Row ID                                               int64
# Order Priority                                      object
# Discount                                           float64
# Unit Price                                         float64
# Shipping Cost                                      float64
# Customer ID                                          int64
# Customer Name                                       object
# Ship Mode                                           object
# Customer Segment                                    object
# Product Category                                    object
# Product Sub-Category                                object
# Product Container                                   object
# Product Name                                        object
# Product Base Margin                                float64
# Region                                              object
# State or Province                                   object
# ...

# %%
df5_Orders_returns.groupby('Product Name')['Status'].count()
# Out:
# Product Name
# #10 White Business Envelopes,4 1/8 x 9 1/2             1
# 12 Colored Short Pencils                               1
# 232                                                    1
# 600 Series Flip                                        1
# 6160                                                   1
#                                                       ..
# Xerox 197                                              2
# Xerox 1980                                             1
# Xerox 1983                                             2
# Xerox 210                                              1
# Zoom V.92 V.44 PCI Internal Controllerless FaxModem    1
# Name: Status, Length: 94, dtype: int64

# %%
p.unique(df2['Region'])
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
df4
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# >>>>>>>>>>>>>>>>>>>>>>>>>find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset >>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
p.unique(df2['Ship Mode'])
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck'], dtype=object)

# %%
s1 = df2.groupby('Ship Mode')['Ship Mode'].count()

# %%
s1
# Out:
# Ship Mode
# Delivery Truck    1283
# Express Air       1107
# Regular Air       7036
# Name: Ship Mode, dtype: int64

# %%
for i in range(0,len(s1)):
    v = (s1[i]/s1.sum())*100
    print(v,s1[i])
    i=i+1
# Out:
# 13.611287927010396 1283
# 11.744112030553786 1107
# 74.64460004243581 7036

# %% [markdown]
# >>>>>>>>>>Regular Air have more usability percentage in the dataset>>>>>>>>>>

# %%
df2.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %% [markdown]
# >>>>>>>>>>>>>>>>>Create a new coulmn and try to find our a diffrence between order date and shipment date>>>>>>>>>

# %%
df2['difference_days_order_shipment'] = (df2 ['Ship Date'] - df2['Order Date']).dt.days

# %%
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
df2.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
df2.dtypes
# Out:
# Row ID                                     int64
# Order Priority                            object
# Discount                                 float64
# Unit Price                               float64
# Shipping Cost                            float64
# Customer ID                                int64
# Customer Name                             object
# Ship Mode                                 object
# Customer Segment                          object
# Product Category                          object
# Product Sub-Category                      object
# Product Container                         object
# Product Name                              object
# Product Base Margin                      float64
# Region                                    object
# State or Province                         object
# City                                      object
# Postal Code                                int64
# Order Date                        datetime64[ns]
# ...

# %%
>>>>>>>base on question number 8 find out for which order id we have shipment duration more than 10 days>>>>>>>

# %%
p.unique(df2[df2['difference_days_order_shipment']>10]['Order ID'])
# Out:
# array([87215, 86318, 87957, 19556, 86177, 88223, 88352, 87572, 91294,
#        86434, 86436, 87300, 19841], dtype=int64)

# %%
df5_Orders_returns.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    1359            Low      0.05        5.85           2.27           21
# 1    1950         Medium      0.01        4.91           0.50          117
# 2    1951         Medium      0.09        4.00           1.30          117
# 3    5055           High      0.02        3.28           5.00          117
# 4    5573            Low      0.02       11.97           5.81          272
#
#           Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
# 1           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 2           Linda Weiss  Express Air      Home Office  Office Supplies  ...
# 3           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 4         Eleanor Swain  Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
df5_Orders_returns['Or_return_difference_days_order_shipment'] = (df5_Orders_returns ['Ship Date'] - df5_Orders_returns['Order Date']).dt.days

# %%
df5_Orders_returns.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0    1359            Low      0.05        5.85           2.27           21
# 1    1950         Medium      0.01        4.91           0.50          117
# 2    1951         Medium      0.09        4.00           1.30          117
# 3    5055           High      0.02        3.28           5.00          117
# 4    5573            Low      0.02       11.97           5.81          272
#
#           Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Tony Wilkins Winters  Regular Air   Small Business  Office Supplies  ...
# 1           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 2           Linda Weiss  Express Air      Home Office  Office Supplies  ...
# 3           Linda Weiss  Regular Air      Home Office  Office Supplies  ...
# 4         Eleanor Swain  Regular Air   Small Business  Office Supplies  ...
#
# ...

# %% [markdown]
# >>>>>>>>>>>>>>>>>10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well >>>>>>>>>>>>>>>>>>>>>>>>>

# %%
df5_Orders_returns[df5_Orders_returns['Or_return_difference_days_order_shipment'] > 15]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, Status, Or_return_difference_days_order_shipment]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# >>>>>>>>>>We do not have a returned order which we have more than 15 days shipment days>>>>>>>>>

# %% [markdown]
# >>>>>>>>>>>>>>>>> Gorup by region and find out which region is more profitable >>>>>>>>>>>>>>>>>>>>>>>>

# %%
df2.groupby('Region')['Profit'].max().nlargest(3)
# Out:
# Region
# South      16332.4140
# Central    12504.9045
# East        9228.2256
# Name: Profit, dtype: float64

# %% [markdown]
# >>>>>We can clearly identify that South Region is more profitable>>>>>>>>>

# %% [markdown]
# >>>>>>>>>>>>>>>>>>>>>>>>>>>Try to find out overalll in which country we are giving more didscount >>>>>>>>>>>

# %%
df2.groupby('State or Province')['Discount'].max().nlargest(5)
# Out:
# State or Province
# Illinois     0.25
# Minnesota    0.17
# Alabama      0.10
# Arizona      0.10
# Arkansas     0.10
# Name: Discount, dtype: float64

# %% [markdown]
# >>>>>We can see from the above data that State Illinois we have given more discount>>>>

# %%
>>>>>>>>>>>>>>>>>>> Give me a list of unique postal code >>>>>>>>>>>>>>>>

# %%
p.unique(df2['Postal Code'])
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %%
>>>>>>>>>>>>>>>>>>>>>>.. which customer segement is more profitalble find it out>>>>>>>>>>>>>>

# %%
df2.groupby('Customer Segment')['Profit'].max().nlargest(5)
# Out:
# Customer Segment
# Home Office       16332.4140
# Corporate         12504.9045
# Small Business    11429.4774
# Consumer           8118.8919
# Name: Profit, dtype: float64

# %% [markdown]
# >>>>>>>Home Office, customer segment is more profitable>>>>>>>>>>>>>>>

# %%
>>>>>>>>>>>>>>>>>>>>>>>>>>>>>Try to find out the 10th most loss making product catagory>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# %%
df2.groupby('Product Category')['Profit'].min().nsmallest()
# Out:
# Product Category
# Technology        -16476.83800
# Office Supplies   -14369.12358
# Furniture         -13706.46400
# Name: Profit, dtype: float64

# %% [markdown]
# We do not have 10th most loss making product category, however from the data we can see that 'Furniture' is the 3rd highest loss making product category

# %%
>>>>>>>>>>>Top 10 product with highest margins>>>>>>>>>>>>

# %%
df2.groupby('Product Name')['Product Base Margin'].max().nlargest(10)
# Out:
# Product Name
# Accessory27                                                                   0.85
# Accessory4                                                                    0.85
# Belkin OmniView SE Rackmount Kit                                              0.85
# Office Impressions Heavy Duty Welded Shelving & Multimedia Storage Drawers    0.85
# Sterling Rubber Bands by Alliance                                             0.85
# Serrated Blade or Curved Handle Hand Letter Openers                           0.84
# Tennsco Commercial Shelving                                                   0.84
# Tennsco Stur-D-Stor Boltless Shelving, 5 Shelves, 24" Deep, Sand              0.84
# *Staples* vLetter Openers, 2/Pack                                             0.83
# Accessory15                                                                   0.83
# Name: Product Base Margin, dtype: float64
