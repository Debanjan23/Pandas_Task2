# %% [markdown]
# 1. #Task 1 - Fitbit Dataset

# %% [markdown]
# 1. Read this dataset in pandas

# %%
import pandas as pn

# %%
df1 = pn.read_csv(r"C:\Users\dchakrab.COMPUTACENTER\Downloads\FitBit_data.csv")

# %%
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04/08/2016       23014      20.389999        20.389999
# 453  8877689391   04/09/2016       16470       8.070000         8.070000
# 454  8877689391   04/10/2016       28497      27.530001        27.530001
# 455  8877689391   04/11/2016       10622       8.060000         8.060000
# 456  8877689391   04/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %% [markdown]
# df1.dtypes

# %% [markdown]
# *********load dataset in pymongo***********

# %%
import pymongo as py

# %%
client = py.MongoClient("mongodb+srv://root:mongodb123@cluster0.zlbwi.mongodb.net/?retryWrites=true&w=majority")
db = client.test

# %%
df1.to_json("FitbitData.json")

# %%
import json

# %%
with open("FitbitData.json") as file:
    file_data=json.load(file)
database = client['FitBitData']
collection = database['FitBitData_table']
collection.insert_one(file_data)

# %% [markdown]
# convert all the dates avaible in dataset to timestamp format in pandas

# %%
df1['converted_activity_date'] = pn.to_datetime(df1['ActivityDate'])

# %%
df1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
>>>>>>>>>>>>Find out in data that how many unique id we have>>>>>>>>>>>>>>>>>>

# %%
pn.unique(df1['Id'])
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
len(pn.unique(df1['Id']))
# Out:
# 35

# %%
>>>>>>>>>>which id is one of the active id that you have in whole dataset>>>>>>>>>>

# %%
df1[df1['VeryActiveMinutes']== max(df1['VeryActiveMinutes'])]['Id']
# Out:
# 304    5577150313
# Name: Id, dtype: int64

# %%
>>>>>>>>>>>>>>>>>>>How many of them have not logged there activity find out in terms of number of ids>>>>>>>>>>>>>>>>

# %%
df2 = df1[df1['LoggedActivitiesDistance'] == 0]

# %%
pn.unique(df2['Id'])
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
len(pn.unique(df2['Id']))
# Out:
# 35

# %%
df1.groupby('Id')['VeryActiveMinutes'].max()
# Out:
# Id
# 1503960366     89
# 1624580081      7
# 1644430081     59
# 1844505072      9
# 1927972279      0
# 2022484408     72
# 2026352035      0
# 2320127002     10
# 2347167796     51
# 2873212765     46
# 2891001357      0
# 3372868164     24
# 3977333714     35
# 4020332650     31
# 4057192912     30
# 4319703577     15
# 4388161847      0
# 4445114986     28
# 4558609924     27
# 4702921684     15
# 5553957443     51
# 5577150313    202
# 6117666160      3
# 6290855005     33
# 6391747486     46
# 6775888955     56
# 6962181067     73
# 7007744171    104
# 7086361926     76
# 8053475328    165
# 8253242879     47
# 8378563200    113
# 8583815059      5
# 8792009665      9
# 8877689391    128
# Name: VeryActiveMinutes, dtype: int64

# %%
>>>>>>>>>>>>>>>>>>>>>>>Find out who is the laziest person id that we have in dataset>>>>>>>>>>>>>

# %%
df1.groupby('Id')['SedentaryMinutes'].max().nlargest(5)
# Out:
# Id
# 1844505072    1440
# 2320127002    1440
# 2873212765    1440
# 2891001357    1440
# 4020332650    1440
# Name: SedentaryMinutes, dtype: int64

# %%
>>>>>>>>>Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy person we have in our dataset>>>>

# %%
len(pn.unique(df1[(df1['Calories']>=2200) & (df1['Calories']<=3000)]['Id']))
# Out:
# 27

# %%
>>>>>>27 people are healthy in terms of daily calorie burn>>>>>>

# %%
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04/08/2016       23014      20.389999        20.389999
# 453  8877689391   04/09/2016       16470       8.070000         8.070000
# 454  8877689391   04/10/2016       28497      27.530001        27.530001
# 455  8877689391   04/11/2016       10622       8.060000         8.060000
# 456  8877689391   04/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df1['converted_activity_week']=df1['converted_activity_date'].dt.week
# Out:
# C:\Users\dchakrab.COMPUTACENTER\AppData\Local\Temp\ipykernel_27064\1326656825.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df1['converted_activity_week']=df1['converted_activity_date'].dt.week

# %%
df1.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
how many person are not a regular person with respect to activity try to find out those.

# %%
df1.groupby('Id')['converted_activity_week'].count().nsmallest()
# Out:
# Id
# 2891001357    8
# 4388161847    8
# 8583815059    8
# 6391747486    9
# 6775888955    9
# Name: converted_activity_week, dtype: int64

# %% [markdown]
# From the above series we can easliy identify that Ids 2891001357, 4388161847, 6391747486,6775888955 and 8583815059 are not regular active person

# %%
>>>>>>>>>>who is the third most active person in this dataset find out those in pandas and in sql both>>>>>>>>>>>>>>

# %%
df1.groupby('Id')['VeryActiveMinutes'].sum().nlargest(3)
# Out:
# Id
# 8053475328    933
# 5577150313    900
# 8877689391    802
# Name: VeryActiveMinutes, dtype: int64

# %%
>>>>>>>>>>>>Who is the 5th most laziest person avilable in dataset find it out>>>>>>>>>>

# %%
df1.groupby('Id')['SedentaryMinutes'].sum().nlargest(5)
# Out:
# Id
# 4057192912    43458
# 4020332650    34663
# 1624580081    24288
# 8253242879    16228
# 1503960366    15387
# Name: SedentaryMinutes, dtype: int64

# %%
>>>>>>>>>>>>>>>>>>>>> what is a total acumulative calories burn for a person find out.>>>>>>>>>>>>>>>>>>

# %%
df1.groupby(['Id','converted_activity_week'])['Calories'].sum()
# Out:
# Id          converted_activity_week
# 1503960366  12                          5917
#             13                         13088
#             14                         13262
#             15                          1861
# 1624580081  12                          3987
#                                        ...
# 8792009665  14                         14500
#             15                          2453
# 8877689391  13                         11611
#             14                         26045
#             15                          3758
# Name: Calories, Length: 103, dtype: int64
